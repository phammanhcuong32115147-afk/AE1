# %% [markdown]
# <a href="https://colab.research.google.com/github/phammanhcuong32115147-afk/AE1/blob/main/B%C3%A0i%20T%E1%BA%ADp%20Tu%E1%BA%A7n%203%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 5
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)

# %%
n = int(input())
if n & (n-1) == 0 :
  print('YES')
else:
  print('NO')
# Out:
# 8
# YES

# %%
import math
m,n  = map(int, input().split())
print(math.floor(m/n))

# %%
import math
m,n  = map(int, input().split())
print(math.ceil(m/n))

# %%
n = int(input())
if n %2==0:
  print('Even')
else:
  print('Odd')

# %%
n,m =map(int,input().split())
if n <0 and m <0:
  print('Yes')
else:
  print('No')

# %%
n = input()
m = input()
if len(a)>len(b):
  print('True')
else:
  print('False')

# %%
a,b,c,d =map(int,input().split())
lst = [a,b,c,d]
print(max(lst))

# %%
a,b,c = map(int, input().split())
if (a + b) > c and (b + c) > a and (a + c) > b:
    if a ==b==c:
        print('Tam giác đều')
    elif a ==b or b==c or a==c:
        print('Tam giác cân')
    else:
        print('Tam giác thường')
else:
    print('Không phải tam giác')

# %%
n = int(input())
if n%4 ==0 and n%(400,100) !=0:
    print('YES')
elif n%400 ==0 :
    print('YES')
else:
    print('NO')

# %%
a,b = map(int, input().split())
if b==0:
    print('Vô Số Nghiệm')
elif a==0:
    print('Vô Nghiệm')
else:
    print(f'{-b/a:.2f}')

# %%
n = float(input())
if n>= 8.0:
    print('Giỏi')
elif  8.0>=n>=6.5:
    print('Khá')
elif 6.5>=n>=5.0:
    print('Trung Bình')
else:
    print('Yếu')

# %%
import math
m,n  = map(int, input().split())
print(math.floor(m/n))
print(math.ceil(m/n))
print(f'{m/n:.0f}')

# %%
a,b,c,d =map(int,input().split())
if b%a ==0:
    q = b/a
    if b*q == c and b*q*q ==d:
        print('YES')
    else:
        print('NO')
else:
    print('NO')
